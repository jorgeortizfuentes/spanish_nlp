# %%
from spanish_nlp import preprocess
sp = preprocess.SpanishPreprocess(
        lower=False,
        remove_url=True,
        remove_hashtags=False,
        split_hashtags=False,
        normalize_breaklines=True,
        remove_emoticons=False,
        remove_emojis=False,
        convert_emoticons=False,
        convert_emojis=False,
        normalize_inclusive_language=False,
        reduce_spam=True,
        remove_reduplications=True,
        remove_vowels_accents=False,
        remove_multiple_spaces=True,
        remove_punctuation=False,
        remove_unprintable=True,
        remove_numbers=False,
        remove_stopwords=False,
        stopwords_list=None,
        lemmatize=False,
        stem=False,
        remove_html_tags=True,
)

text = """
"@asteinsapir @CaceresJoo @gabrielboric @paulanarvaezo @yasnaprovoste @danieljadue No van a llegar, al poder....no podemos ser tan wns los chilenos, para repetir la historia de los 70... 
#RechazoDeSalida 
#RechazoDeSalida 
#RechazoDeSalida 
#RechazoDeSalida 
#RechazoDeSalida 
#RechazoDeSalida 
#RechazoDeSalida 
#RechazoDeSalida 
#RechazoDeSalida
# """

text = """ 
😂 😂 😂 😂 😂 pobre weon inepto, imbécil, esperpento das pena.. tus comentarios reflejan de cuerpo y alma el pensamiento de los fachos pobres... que se basa en la aspiración de sde un fra fra algún día. Weon mediocre.. Saludos 😂 😂 😂
"""

text = """
"Manual para defender al camarada de la secta✊👹☭:
""Operación grotesca""
""Apoyo popular""
""Demandas populares""
Tienen al Che por justiciero social y al FPMR,MIR,CAM,ETC por formas románticas para lograr objetivos.Abyectos mitómanos negacionistas igual que sus ídolos y referentes✊ https://t.co/lAbM3upKLC https://t.co/lWQRx8jny2"
"""
print(sp.transform(text, debug=True))
# Out:
# Method: remove_url
# ------------------------------------------------------------------------------------------
# Text:
# "Manual para defender al camarada de la secta✊👹☭:
# ""Operación grotesca""
# ""Apoyo popular""
# ""Demandas populares""
# Tienen al Che por justiciero social y al FPMR,MIR,CAM,ETC por formas románticas para lograr objetivos.Abyectos mitómanos negacionistas igual que sus ídolos y referentes✊
#
# ========================================================================================================================
# Method: remove_html_tags
# ------------------------------------------------------------------------------------------
# Text:
# "Manual para defender al camarada de la secta✊👹☭:
# ""Operación grotesca""
# ""Apoyo popular""
# ""Demandas populares""
# Tienen al Che por justiciero social y al FPMR,MIR,CAM,ETC por formas románticas para lograr objetivos.Abyectos mitómanos negacionistas igual que sus ídolos y referentes✊
#
# ========================================================================================================================
# Method: emojis_to_text
# ------------------------------------------------------------------------------------------
# Text:
# "Manual para defender al camarada de la secta __raised_fist__  __ogre__ ☭:
# ""Operación grotesca""
# ""Apoyo popular""
# ""Demandas populares""
# Tienen al Che por justiciero social y al FPMR,MIR,CAM,ETC por formas románticas para lograr objetivos.Abyectos mitómanos negacionistas igual que sus ídolos y referentes __raised_fist__
#
# ========================================================================================================================
# Method: emoticons_to_text
# ------------------------------------------------------------------------------------------
# Text:
# "Manual para defender al camarada de la secta __raised_fist__  __ogre__ ☭:
# ""Operación grotesca""
# ""Apoyo popular""
# ""Demandas populares""
# Tienen al Che por justiciero social y al FPMR,MIR,CAM,ETC por formas románticas para lograr objetivos.Abyectos mitómanos negacionistas igual que sus ídolos y referentes __raised_fist__
#
# ========================================================================================================================
# Method: remove_reduplications
# ------------------------------------------------------------------------------------------
# Text:
# "Manual para defender al camarada de la secta _raised_fist_ _ogre_ ☭:
# "Operación grotesca"
# "Apoyo popular"
# "Demandas populares"
# Tien al Che por justiciero social y al FPMR,MIR,CAM,ETC por formas románticas para lograr objetivos.Abyectos mitómanos negacionistas igual que sus ídolos y referentes _raised_fist_
#
# ========================================================================================================================
# Method: remove_unprintable
# ------------------------------------------------------------------------------------------
# Text:
# "Manual para defender al camarada de la secta _raised_fist_ _ogre_ :
# "Operación grotesca"
# "Apoyo popular"
# "Demandas populares"
# Tien al Che por justiciero social y al FPMR,MIR,CAM,ETC por formas románticas para lograr objetivos.Abyectos mitómanos negacionistas igual que sus ídolos y referentes _raised_fist_
#
# ========================================================================================================================
# Method: text_to_emojis (not delete emojis)
# ------------------------------------------------------------------------------------------
# Text:
# "Manual para defender al camarada de la secta _raised_fist_ _ogre_ :
# "Operación grotesca"
# "Apoyo popular"
# "Demandas populares"
# Tien al Che por justiciero social y al FPMR,MIR,CAM,ETC por formas románticas para lograr objetivos.Abyectos mitómanos negacionistas igual que sus ídolos y referentes _raised_fist_
#
# ========================================================================================================================
# Method: text_to_emoticons (not delete emoticons)
# ------------------------------------------------------------------------------------------
# Text:
# "Manual para defender al camarada de la secta _raised_fist_ _ogre_ :
# "Operación grotesca"
# "Apoyo popular"
# "Demandas populares"
# Tien al Che por justiciero social y al FPMR,MIR,CAM,ETC por formas románticas para lograr objetivos.Abyectos mitómanos negacionistas igual que sus ídolos y referentes _raised_fist_
#
# ========================================================================================================================
# Method: remove_multiples_spaces
# ------------------------------------------------------------------------------------------
# Text: "Manual para defender al camarada de la secta _raised_fist_ _ogre_ :
# "Operación grotesca"
# "Apoyo popular"
# "Demandas populares"
# Tien al Che por justiciero social y al FPMR,MIR,CAM,ETC por formas románticas para lograr objetivos.Abyectos mitómanos negacionistas igual que sus ídolos y referentes _raised_fist_
# ========================================================================================================================
# Method: normalize_breaklines
# ------------------------------------------------------------------------------------------
# Text: "Manual para defender al camarada de la secta _raised_fist_ _ogre_ :
# "Operación grotesca"
# "Apoyo popular"
# "Demandas populares"
# Tien al Che por justiciero social y al FPMR,MIR,CAM,ETC por formas románticas para lograr objetivos.Abyectos mitómanos negacionistas igual que sus ídolos y referentes _raised_fist_
# ========================================================================================================================
# Method: normalize_punctuation_spelling
# ------------------------------------------------------------------------------------------
# Text: "Manual para defender al camarada de la secta _raised_fist_ _ogre_:
# "Operación grotesca"
# "Apoyo popular"
# "Demandas populares"
# Tien al Che por justiciero social y al FPMR,MIR,CAM,ETC por formas románticas para lograr objetivos.Abyectos mitómanos negacionistas igual que sus ídolos y referentes _raised_fist_
# ========================================================================================================================
# Method: reduce_spam
# ------------------------------------------------------------------------------------------
# Text: "Manual para defender al camarada de la secta _raised_fist_ _ogre_:
# "Operación grotesca"
# "Apoyo popular"
# "Demandas populares"
# Tien al Che por justiciero social y al FPMR,MIR,CAM,ETC por formas románticas para lograr objetivos.Abyectos mitómanos negacionistas igual que sus ídolos y referentes _raised_fist_
# ========================================================================================================================
# "Manual para defender al camarada de la secta _raised_fist_ _ogre_:
# "Operación grotesca"
# "Apoyo popular"
# "Demandas populares"
# Tien al Che por justiciero social y al FPMR,MIR,CAM,ETC por formas románticas para lograr objetivos.Abyectos mitómanos negacionistas igual que sus ídolos y referentes _raised_fist_

# %%
import re
def _reduce_spam_(text):
    """Reduce spam in text when a expression is repeated more than 3 times.
    Example: "hola hola hola hola hola hola" -> "hola hola hola" """
    text = re.sub(r"(#\w+\s)\1+", r"\1\1", text, flags=re.DOTALL)
    text = re.sub(r"(\w+\s)\1+", r"\1\1", text, flags=re.DOTALL)
    text = re.sub(r"(\b(\w+\s){3})\1+", r"\1\1", text, flags=re.DOTALL)
    return text

_reduce_spam_(text)
# Out:
# '\n"@asteinsapir @CaceresJoo @gabrielboric @paulanarvaezo @yasnaprovoste @danieljadue No van a llegar, al poder....no podemos ser tan wns los chilenos, para repetir la historia de los 70... \n#RechazoDeSalida \n#RechazoDeSalida \n#RechazoDeSalida \n#RechazoDeSalida \n#RechazoDeSalida \n#RechazoDeSalida \n#RechazoDeSalida \n#RechazoDeSalida \n#RechazoDeSalida\n# '

# %%
import re

def rs(text):
    """Reduce spam in text when a expression is repeated more than 3 times.
    Example: "hola hola hola hola hola hola" -> "hola hola hola" """
    text = re.sub(r"(\w+\s)\1+", r"\1\1", text)
    text = re.sub(r"(\b(\w+\s){3})\1+", r"\1\1", text)
    return text

rs("No van a llegar, al poder.... no podemos ser tan wns los chilenos, para repetir la historia de los 70... Rechazo De Salida Rechazo De Salida Rechazo De Salida Rechazo De Salida Rechazo De Salida Rechazo De Salida Rechazo De Salida Rechazo De Salida Rechazo De Salida #")
# Out:
# 'No van a llegar, al poder.... no podemos ser tan wns los chilenos, para repetir la historia de los 70... Rechazo De Salida Rechazo De Salida #'

# %%
import re

def _remove_reduplications_(self, text):
    """Use a regular expression to find a sequence of non-digit characters
    that are repeated at the end of the word, and replace it with just
    one instance of the character"""
    # Replace ... with …
    text = re.sub(r'\.{3,}', '…', text)
    text = re.sub(r'(?i)(.+?)\1+', r'\1', text)
    # Replace … with ...
    text = re.sub(r'…', '...', text)
    return text


texts = ["gooool", "holaaaa", "wena ctmmm", "AAAAAA", "hola...", "tienen"]

for text in texts:
    print(remove_reduplications(text))
# Out:
# gol
# hola
# wena ctm
# A
# hola.

# %%
import re
def remove_reduplications(text):
    # "Replace ... with …"
    text = re.sub(r'\.{3,}', '…', text)
    text = re.sub(r'(?i)(.+?)\1+', r'\1', text)
    # "Replace … with ..."
    text = re.sub(r'…', '...', text)
    return text

texts = ["gooool", "holaaaa", "wena ctmmm", "AAAAAA", "hola...", "hola. Cómo estás?, no se ... y tu?"]
for text in texts:
    print(remove_reduplications(text))
# Out:
# gol
# hola
# wena ctm
# A
# hola...
# hola. Cómo estás?, no se ... y tu?

# %%
"gooooool" -> "gol"
"holaaaaa" -> "hola"
"maricoo" -> "marico"
"HOLAAA" -> "HOLA"
